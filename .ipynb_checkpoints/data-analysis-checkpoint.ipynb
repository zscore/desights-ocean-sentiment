# %%
# Data Analysis (50 points)
# Based on the data in the provided datasets, address the following questions:
# Calculate the correlation between the price of $OCEAN and the number of tweets containing "$OCEAN". What conclusions can be drawn from this correlation?
# Determine the correlation between the price of $OCEAN and the number of likes received by tweets containing "$OCEAN". What insights can be derived from this correlation?
# Establish the correlation between the price of $OCEAN and the number of retweets generated by tweets containing "$OCEAN". What conclusions can be made from this correlation?
# Assess the correlation between the price of $OCEAN and the number of individuals tweeting with the cashtag "$OCEAN". What conclusions can be drawn from this correlation?

# Analyze the impact of influential tweets on the price of the OCEAN token. What conclusions can be drawn from this analysis?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tweets_df = pd.read_csv("./datasets/$OCEAN tweets dataset.csv")
prices_df = pd.read_csv("./datasets/OCEAN token price dataset.csv")
sentiment_df = pd.read_csv("./derived_datasets/twitter-roberta-base-sentiment.csv")

# %%
sentiment_df["positive_index"] =  sentiment_df["positive"] - sentiment_df["neutral"]
sentiment_tweets_df = sentiment_df.merge(tweets_df, left_on="tweet_id", right_on="id")
sentiment_tweets_df["date_dt"] = pd.to_datetime(sentiment_tweets_df["date"])
sentiment_tweets_df["likes_pos_idx"] = sentiment_tweets_df["likes_count"] * sentiment_tweets_df["positive_index"]

# %%
daily_sentiment_df = sentiment_tweets_df.groupby("date_dt")[["likes_pos_idx", "likes_count"]].sum()
daily_sentiment_df["weight_pos_idx"] = (daily_sentiment_df["likes_pos_idx"] / daily_sentiment_df["likes_count"])
daily_sentiment_df["weight_pos_idx"].describe()
# Out:
# count    1024.000000
# mean        0.023917
# std         0.200230
# min        -0.605122
# 25%        -0.106558
# 50%         0.013514
# 75%         0.145503
# max         0.694428
# Name: weight_pos_idx, dtype: float64

# %%
prices_df["date_dt"] = pd.to_datetime(prices_df["Date"])

# %%
tweets_df["date_dt"] = pd.to_datetime(tweets_df["date"])

# %%
tweets_prices_df = tweets_df.merge(prices_df, on="date_dt")

# %%
tweets_df["has_ocean_cashtag"] = tweets_df["tweet"].apply(lambda t: "$OCEAN" in t)

# %%
daily_tweets_df = tweets_df.query("has_ocean_cashtag").groupby("date_dt").agg({"has_ocean_cashtag": ["sum"],
                                                                               "likes_count": ["mean", "sum", "median", "max"],
                                                                               "retweets_count": ["mean", "sum", "median"],
                                                                               "user_id": [pd.Series.nunique]})

# %%
daily_tweets_df.columns = ['_'.join(col).strip() for col in daily_tweets_df.columns.values]

# %%
prices_daily_tweets_df = prices_df.merge(daily_tweets_df.reset_index(), on="date_dt")

# %%
tweets_prices_sentiment_df = tweets_prices_df.merge(daily_sentiment_df.reset_index(), on="date_dt")

# %%
daily_tweets_df.corr()
# Out:
#                        has_ocean_cashtag_sum  likes_count_mean  \
# has_ocean_cashtag_sum               1.000000          0.180036
# likes_count_mean                    0.180036          1.000000
# likes_count_sum                     0.837917          0.552245
# likes_count_median                 -0.040765          0.523766
# likes_count_max                     0.387471          0.668565
# retweets_count_mean                 0.136333          0.734223
# retweets_count_sum                  0.737800          0.453392
# retweets_count_median               0.231931          0.195413
# user_id_nunique                     0.969883          0.239026
#
#                        likes_count_sum  likes_count_median  likes_count_max  \
# has_ocean_cashtag_sum         0.837917           -0.040765         0.387471
# likes_count_mean              0.552245            0.523766         0.668565
# likes_count_sum               1.000000            0.133707         0.664611
# ...

# %%
tweets_prices_sentiment_df.corr()
# Out:
#                        id  conversation_id  timezone   user_id  place  \
# id               1.000000         0.998624       NaN  0.238517    NaN
# conversation_id  0.998624         1.000000       NaN  0.239023    NaN
# timezone              NaN              NaN       NaN       NaN    NaN
# user_id          0.238517         0.239023       NaN  1.000000    NaN
# place                 NaN              NaN       NaN       NaN    NaN
# replies_count    0.003767         0.003840       NaN -0.015326    NaN
# retweets_count  -0.011559        -0.011336       NaN -0.012745    NaN
# likes_count_x   -0.001764        -0.001495       NaN -0.034922    NaN
# retweet               NaN              NaN       NaN       NaN    NaN
# video            0.078160         0.077713       NaN  0.050540    NaN
# near                  NaN              NaN       NaN       NaN    NaN
# geo                   NaN              NaN       NaN       NaN    NaN
# ...

# %%
prices_daily_tweets_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'date_dt', 'has_ocean_cashtag_sum', 'likes_count_mean',
#        'likes_count_sum', 'likes_count_median', 'likes_count_max',
#        'retweets_count_mean', 'retweets_count_sum', 'retweets_count_median',
#        'user_id_nunique'],
#       dtype='object')

# %%
prices_daily_tweets_df[["likes_count_sum", "retweets_count_sum", "user_id_nunique", "Close"]].corr()
# Out:
#                     likes_count_sum  retweets_count_sum  user_id_nunique  \
# likes_count_sum            1.000000            0.878021         0.864697
# retweets_count_sum         0.878021            1.000000         0.758622
# user_id_nunique            0.864697            0.758622         1.000000
# Close                      0.575971            0.480441         0.542722
#
#                        Close
# likes_count_sum     0.575971
# retweets_count_sum  0.480441
# user_id_nunique     0.542722
# Close               1.000000

# %%
prices_daily_tweets_df["open_minus_close"] = (prices_daily_tweets_df["Open"] - prices_daily_tweets_df["Close"]) 
prices_daily_tweets_df["open_minus_close_pct"] = (prices_daily_tweets_df["Open"] - prices_daily_tweets_df["Close"]) / prices_daily_tweets_df["Open"] * 100

# %%
prices_daily_tweets_df[list(daily_tweets_df.columns) + ["Close", "open_minus_close", "open_minus_close_pct"]].corr()
# Out:
#                        has_ocean_cashtag_sum  likes_count_mean  \
# has_ocean_cashtag_sum               1.000000          0.180036
# likes_count_mean                    0.180036          1.000000
# likes_count_sum                     0.837917          0.552245
# likes_count_median                 -0.040765          0.523766
# likes_count_max                     0.387471          0.668565
# retweets_count_mean                 0.136333          0.734223
# retweets_count_sum                  0.737800          0.453392
# retweets_count_median               0.231931          0.195413
# user_id_nunique                     0.969883          0.239026
# Close                               0.478844          0.303864
# open_minus_close                   -0.193671         -0.105915
# open_minus_close_pct               -0.171073         -0.116865
#
#                        likes_count_sum  likes_count_median  likes_count_max  \
# ...

# %%
_ = prices_daily_tweets_df.plot(x="has_ocean_cashtag_sum", y="likes_count_sum", kind="scatter")

# %%
_ = prices_daily_tweets_df.plot(x="has_ocean_cashtag_sum", y="retweets_count_sum", kind="scatter")

# %%
_ = prices_daily_tweets_df.plot(x="has_ocean_cashtag_sum", y="user_id_nunique", kind="scatter")

# %%
_ = prices_daily_tweets_df.iloc[300:].plot(x="likes_count_sum", y="Close", kind="scatter")
plt.xscale("log")
_ = prices_daily_tweets_df.plot(x="retweets_count_sum", y="Close", kind="scatter")
plt.xscale("log")
_ = prices_daily_tweets_df.plot(x="user_id_nunique", y="Close", kind="scatter")
plt.xscale("log")
_ = prices_daily_tweets_df.plot(x="likes_count_max", y="Close", kind="scatter")
plt.xscale("log")

# %%
_ = prices_daily_tweets_df.plot(x="likes_count_max", y="open_minus_close", kind="scatter")
plt.xscale("log")

# %%
_ = prices_daily_tweets_df.plot(x="likes_count_max", y="open_minus_close", kind="scatter")
plt.xscale("log")

# %%
_ = prices_daily_tweets_df.plot(x="likes_count_max", y="open_minus_close_pct", kind="scatter")
plt.xscale("log")

# %%
_  = prices_df.plot(x="date_dt", y="Close")

# %%
prices_daily_tweets_df[["Close", "has_ocean_cashtag_sum", "likes_count_sum", "retweets_count_sum", "user_id_nunique"]].corr()

# %%
# redo all of these plots but subtract the 30 or 90 day moving average instead

# %%
prices_daily_tweets_df["close_minus_90_mavg"] = prices_daily_tweets_df["Close"] - prices_daily_tweets_df["Close"].rolling(window=365).mean()

# %%
_ = prices_daily_tweets_df.plot(x="likes_count_sum", y="close_minus_90_mavg", kind="scatter")
plt.xscale("log")
# _ = prices_daily_tweets_df.plot(x="retweets_count_sum", y="close_minus_90_mavg", kind="scatter")
# _ = prices_daily_tweets_df.plot(x="user_id_nunique", y="close_minus_90_mavg", kind="scatter")

# %%
# todo: filter to only the top retweeted tweets and compare the open minus the close on that day or perhaps the open/close on the next day

# %%
_ = prices_daily_tweets_df.plot(x="Close", y="retweets_count_sum", kind="scatter")

# %%
prices_df.shape
