# %%
import numpy as np
import pandas as pd

# %%
tweets_df = pd.read_csv("./datasets/$OCEAN tweets dataset.csv")

# %%
sentiment_scores_df = pd.read_csv("./derived_datasets/twitter-roberta-base-sentiment.csv")

# %%
tweets_sentiment_df = tweets_df.merge(sentiment_scores_df,
                                      left_on="id",
                                      right_on="tweet_id")

# %%
labels_dict = {1428027100154540032: "neutral",
 1226377358233522176: "positive",
 1324338428763381764: "positive",
 1544067716901998592: "positive",
 1368508346337214464: "neutral",
 1334543909293322242: "negative",
 1332267736953737223: "neutral",
 1297379576054550528: "neutral",
 1372572836318085127: "positive",
 1270397698940850180: "positive",
 1346864622855483392: "neutral",
               }

# %%
labels[row["id"]]
# Out:
# 'negative'

# %%
labels_from_google_drive = pd.read_clipboard()

# %%
labels_from_google_drive[["id", "Labels"]].iloc[:100].to_csv("./derived_datasets/labels.csv",
                                                             index=False)

# %%
clean_labels_from_google_drive = pd.read_csv("./derived_datasets/labels.csv")

# %%
clean_labels_from_google_drive["Labels"].map({1: "positive",
                                              0: "neutral",
                                              -1: "negative"})
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#      ...
# 95    NaN
# 96    NaN
# 97    NaN
# 98    NaN
# 99    NaN
# Name: Labels, Length: 100, dtype: object

# %%
tweets_sentiment_df["sentiment_classification"] = tweets_sentiment_df[labels].apply(np.argmax, axis=1) - 1

# %%
clean_labels_from_google_drive = pd.read_csv("./derived_datasets/sampled_tweets.csv")

# %%
joined_df = tweets_sentiment_df.merge(
    clean_labels_from_google_drive[["tweet", "Labels"]],
    on="tweet",
    suffixes=["", "_label"])[["tweet", "sentiment_classification", "Labels"]].drop_duplicates()

# %%
joined_df.groupby(["sentiment_classification", "Labels"]).count()
# Out:
#                                  tweet
# sentiment_classification Labels
# -1                       -           1
#                          -1          2
#                          0           1
#  0                       -           4
#                          -1          5
#                          0          21
#                          1          14
#  1                       -1          1
#                          0          15
#                          1          36

# %%
filt_df = joined_df.query("Labels != '-'")

# %%
filt_df["Labels"][0]
# Out:
# '0'

# %%
filt_df["sentiment_classification"]
# Out:
# 0      0
# 334    0
# 335    0
# 336    1
# 337    1
#       ..
# 430    1
# 431    1
# 432    1
# 433    1
# 434    1
# Name: sentiment_classification, Length: 95, dtype: int64

# %%
joined_df.query("Labels == '-'").shape[0] / joined_df.shape[0]
# Out:
# 0.05

# %%
np.mean(filt_df["Labels"].apply(int) == filt_df["sentiment_classification"])
# Out:
# 0.6210526315789474

# %%
np.mean(np.abs(filt_df["Labels"].apply(int) - filt_df["sentiment_classification"]) <= 1)
# Out:
# 0.9894736842105263

# %%
precision_df = ["Labels"] == joined_df.query("Labels != '-'")["Tweet]
# Out:
#   Cell In[133], line 1
#     precision_df = joined_df.query("Labels != '-'")["Labels"] != joined_df.query("Labels != '-'")["Tweet]
#                                                                                                          ^
# SyntaxError: EOL while scanning string literal

# %%
precision_df.drop_duplicates()
# Out:
#      index                   id      conversation_id  \
# 0        0  1582371288592486400  1582371288592486400
# 1        1  1578464213043130368  1578464213043130368
# 2        2  1573122733269192704  1573122733269192704
# 3        3  1569943297577349120  1569943297577349120
# 4        4  1567484310189375490  1567484310189375490
# ..     ...                  ...                  ...
# 430    430  1290029749704613888  1289891636483444739
# 431    431  1285053019973984256  1285053019973984256
# 432    432  1270397698940850180  1270253683784273920
# 433    433  1265616267223891968  1264808024218259456
# 434    434  1263111456595292161  1263111456595292161
#
#                                 created_at        date      time  timezone  \
# 0    2022-10-18 17:01:28 GTB (heure d’été)  2022-10-18  17:01:28       300
# 1    2022-10-07 22:16:09 GTB (heure d’été)  2022-10-07  22:16:09       300
# 2    2022-09-23 04:31:01 GTB (heure d’été)  2022-09-23  04:31:01       300
# 3    2022-09-14 09:57:04 GTB (heure d’été)  2022-09-14  09:57:04       300
# 4    2022-09-07 15:05:56 GTB (heure d’été)  2022-09-07  15:05:56       300
# ..                                     ...         ...       ...       ...
# 430  2020-08-03 00:00:34 GTB (heure d’été)  2020-08-03  00:00:34       300
# 431  2020-07-20 06:24:49 GTB (heure d’été)  2020-07-20  06:24:49       300
# 432  2020-06-09 19:49:48 GTB (heure d’été)  2020-06-09  19:49:48       300
# 433  2020-05-27 15:10:06 GTB (heure d’été)  2020-05-27  15:10:06       300
# 434  2020-05-20 17:16:53 GTB (heure d’été)  2020-05-20  17:16:53       300
#
#                  user_id         username                       name  ...  \
# 0     989986772108095490   dontgetfooled2             WhySoSerious?!  ...
# 1             2317413794       cemgymstar  cemyildiz.lens is Bored 👹  ...
# 2             4904522150  bayuwardhanaaja         #EuroShibaInu Army  ...
# 3    1211580821020168192  sirabdullahsidd          Abdullah Siddiqui  ...
# 4    1094937593677074432     misterproton               Misterproton  ...
# ..                   ...              ...                        ...  ...
# 430   944574535864602624      lordtuanjim                   Jester 🌍  ...
# 431             96867153        martytalk                    marty 🤙  ...
# 432  1260253107390464001    fabergecrypto               En Sabah Nur  ...
# 433  1238918864467120132        mooncruse                  MoonCruse  ...
# 434           1966387794  thecryptofessor          Martijn vd Weerdt  ...
#
#      retweet_date translate trans_src trans_dest  negative   neutral  \
# 0             NaN       NaN       NaN        NaN  0.134665  0.705341
# 1             NaN       NaN       NaN        NaN  0.134665  0.705341
# 2             NaN       NaN       NaN        NaN  0.134665  0.705341
# 3             NaN       NaN       NaN        NaN  0.134665  0.705341
# 4             NaN       NaN       NaN        NaN  0.134665  0.705341
# ..            ...       ...       ...        ...       ...       ...
# 430           NaN       NaN       NaN        NaN  0.022482  0.269874
# 431           NaN       NaN       NaN        NaN  0.052014  0.454509
# 432           NaN       NaN       NaN        NaN  0.091116  0.445846
# 433           NaN       NaN       NaN        NaN  0.003211  0.024007
# 434           NaN       NaN       NaN        NaN  0.084733  0.357608
#
#      positive             tweet_id  sentiment_classification Labels
# 0    0.159994  1582371288592486400                         0      0
# 1    0.159994  1578464213043130368                         0      0
# 2    0.159994  1573122733269192704                         0      0
# 3    0.159994  1569943297577349120                         0      0
# 4    0.159994  1567484310189375490                         0      0
# ..        ...                  ...                       ...    ...
# 430  0.707644  1290029749704613888                         1      1
# 431  0.493477  1285053019973984256                         1      1
# 432  0.463038  1270397698940850180                         1      1
# 433  0.972783  1265616267223891968                         1      1
# 434  0.557658  1263111456595292161                         1      0
#
# [430 rows x 43 columns]

# %%
tweets_sentiment_df["sentiment_classification"].describe()
# Out:
# count    229857.000000
# mean          0.329661
# std           0.554308
# min          -1.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           1.000000
# Name: sentiment_classification, dtype: float64

# %%
# for i, row in tweets_sentiment_df.iterrows():
#     row[labels]
# # np.argmax()

# %%
clean_labels_from_google_drive["Labels"]
# Out:
# 0     -1
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 95     0
# 96     1
# 97     0
# 98     0
# 99     0
# Name: Labels, Length: 100, dtype: object

# %%
np.random.seed(100101)
labels = ['negative', 'neutral', 'positive']
tweets_sentiment_df.sample(100).to_excel("./derived_datasets/sampled_tweets.xls")
for i, row in tweets_sentiment_df.sample(100).iterrows():
    if row["id"] not in labels_dict:
        print(row["id"])
        print(row["tweet"])
    # print(row[labels])
# Out:
# 1297445485951643648
# I am part of the martkist community now, come join us #Martkist #socialmedia #Faucet $Martk $eth $btc $link $xrp $om $ampl $yam $ocean $kai $mitx #Binance #Bitcoin  https://t.co/IrYXbwIYgf
# 1296874987593203712
# Want to earn crypto ? join the martkist faucet and get paid $Martk #Martkist  https://t.co/ncvC9Dv94V  https://t.co/htqQbxWdKb $eth $btc $link $xrp $om $ampl $yam $ocean $kai $mitx $tmpl
# 1412119429073231874
# @oceanprotocol @Datarella @IAAmobility @BoschGlobal @MOBIX_AI @Fetch_ai $OCEAN keeps delivering
# 1450471276318007306
# @eliz883 $Ocean is tripping now
# 1315616675744673792
# @TheDaoMaker $EWT is my biggest bag and I'm always loading it if I can. I'm also holding $BTC $LINK $UTK and $OCEAN but $EWT is my favorite one!  Projects has the world’s largest #energy #blockchain #ecosystem.  https://t.co/0bt6DL56qH
# 1567328780661956608
# @CoinbaseAssets Finally!!! $OCEAN entered to the list of @Coinbase @CoinbaseAssets   🐋
# 1384009472369061892
# SOT $$$$ $ALGO $WAVES $FTM $ANT $OMG $XTZ $OCEAN $REN $UNI $YFI $YFII $BAT $BUSD $DAI $ENJ $KNC $LINK $STAKE $MANA $MKR $REN $REP $MATCH $RSR $DEFI $BAND $ALPHA $ICX $RUNE $KSM $LUNA $MIR $DOT $VET $ZIL $AKRO $FET $COTI $SUSHI $GNY $SOL $ATOM $UTK  https://t.co/39DX1ssVN1  https://t.co/fSYJ38yQRT
# 1296700338271956992
# @TradeOgre add $Martk #Martkist we have a great community @Martkist #Martkist #socialmedia #Faucet $Martk $eth $btc $link $xrp $om $ampl $yam $ocean $kai $mitx #Binance #Bitcoin
# 1346539572143026189
# @h_bitcoiner $OCEAN will power a lot of smart cities in the future
# 1575575498994102272
# 7.62m $OCEAN locked in less than one week of veOCEAN launch.  I can only imagine how many $OCEAN will be removed from circulation in 6 months time.  #web3 #defi #ai #crypto  https://t.co/OprePmsSAk
# 1352637051632558080
# @CryptoGodJohn $DOT $RSR $LINK $OCEAN $ATOM 🚀🚀🚀🚀
# 1362758079687843847
# $btc $eth $ltc $req $dock $gvt $fxs $poly $sky $loom $ark $bnt $ftm $xvs $bnb $kcs $fet $utk $rvn $matic $ksm $xrt $dot $uni $snx $ren $zrx $dash $xmr $etc $nano $trx $xlm $xrp $ocean $key $front $revv $dodo $doge
# 1486728738586824718
# World leaders forced to sell at all time highs, are we getting this alt season? $OCEAN / $BTC
# 1466034450869866502
# @IncomeTokens #whitelist #whitelisted #getwhitelisted $OCEAN $FEG $RUNE $PINKSALE #PINKSALE #DXSALE #IDO #ICO #AVAX $ETHM $ALLBI $GSHIB $MPX $ISLA #PINKSALE #IDO $RWSC $DSG $NELO $NFTD $ECN #PINKSALE #IDO $SHIBA $SHIB $EXMR $AMA #PINKSALE #IDO #ICO $ILV $SAND #IDO #PINKSALE #DXSALE #ICO
# 1321210126934536192
# 📈 Biggest Gainers (1 hr) 📈 Uquid Coin $UQC 22.15% 🔥🔥🔥 Ocean Protocol $OCEAN 3.02% 🔥 Basic Attention Token $BAT 2.13% 🔥 aelf $ELF 1.77% 🔥 Horizen $ZEN 1.47% 🔥
# 1391734195232333824
# $OCEAN Update Good for a quick 11% gain on that breakout on the daily, would pay some attention now as we're hitting the red resistance box, flip of that and we are good to go for new ATH's. BTC pairing is a bit more clear, still has to breakout and fighting with the red box.  https://t.co/z8gxrB6NVO
# 1400006225404731394
# @3ree6ixty Forget the usuals. $ocean, long term! Thank me later
# 1336704931797975040
# Wow, I've been pushing for $ocean on @AaveAave, since July. 🥲
# 1577456334873706496
# [Scan results - #Binance - 15m]  Top 5 bullish trends on $BTC pair 1: $BTCST 2: $FXS 3: $HNT 4: $CAKE 5: $SAND  Top 5 bullish trends on $USDT pair 1: $OCEAN 2: $MDT 3: $SAND 4: $DOGE 5: $NEAR  All Binance results:  https://t.co/NE27I4BsNN Not buy signals. #DYOR
# 1451946685999968260
# $OCEAN
# 1524766175997030403
# Min USD Funding has been live in Round 17, going on in Round 18.  By defining a significantly lower amount that you would accept as minimum funding, you increase the probability of you getting funded with (some) $OCEAN significantly.
# 1421932427014926339
# $BTC trade did 300% in 2 days after alert..   $BTC $ETH $ADA $XRP $DOT $KSM $BNB $RUNE $OCEAN $RSR $REN $LINK $ICX $INJ $CHZ $VET $WIN $FET $WRX $ENJ $BTT  https://t.co/SWx5lGLtFA
# 1351579542062682115
# Crypto Observations  $ETH over $1400.  $2000 Target looking inevitable 🚀  $DOT and $ADA challengers to #ETHEREUM 👑  $RSR and $OCEAN still waiting to breakout  $LUNA making a nice run  $MPH is a runaway 🚂  $EXRD still flying under the radar  So many #Altcoins charts look ready
# 1303996944054915073
# Martkist join us and generate $Martk with your social media account  https://t.co/lnWT9ixINq $eth $btc $link $xrp $om $ampl $yam $ocean $kai $mitx $tmpl
# 1511616649547464705
# Congratz @kaushikkg on long position👏  ✅Symbol : $BNX ✅ROE : %80.98 ✅Entry : 105.8822 ✅Exit : 110.35  Follow top ROI people realtime. Link on profile and pinned tweet $UNI $REEF $ANC $OMG $XRP $NEAR $ZEC $OCEAN $GTC $KAVA
# 1528461526964834305
# @kucoincom 1.  $OCEAN 2. $CARD 3. $ETH 4. $DFI  #BullishAF #DeFi
# 1334608278681251841
# Another #Crypto #Giveaway #Competition   #Bitcoin #DeFi $BTC $ETH $LINK $KSM $CLIQ $OCEAN @polkadot
# 1299667751703736320
# Find your local business with a Martkist partnership $Mark  https://t.co/NWlUm8H5Zq $eth $btc $link $xrp $om $ampl $yam $ocean $kai $mit
# ⛔ $OCEAN decreased by -4.45%   💵 Price - 0.40440000   -- Sun Sep 06 2020 20:07:45 GMT+0000 (Coordinated Universal Time)    #Crypto #CryptoBot #OCEANUSDT #OCEAN
# 1272810910457802752
# My Current moon bags:  $coti $lcx $ewt $ocean $link $rune $chr $noia   See y’all up there
# 1375909376343543813
# Rather I know yaw or not I feel like we all in this together $vra $dext $sha $ftm $nim $vet $ubx $sntvt $bepro $mtv $bax $tel $cov $dag $ltx $btc $mitx $ocean $nioa $coti $akro $fet $agi $eth $ada $xrp an all the other $alts #crypto 🚀🚀🚀
# 1359214011204521991
# What a wild day yesterday was for $DEC but there is a lot of room left to run on this throughout 2021. See this rivaling $BAT or jumping it this bull run. Data is such a big money space.  Ps follow @wenmhoon (he called $Dec under .04).  $dec Roadmap below. $ocean $utu $dia $sxp
# 1357374837765849088
# #elonMask #OCEAN PROTOCOL $OCEAN
# 1578607817707192320
# [Scan results - #KuCoin - 15m]  Top 5 bullish trends on $BTC pair 1: $ZEC 2: $NEO 3: $INJ 4: $CRO 5: $CPC  Top 5 bullish trends on $USDT pair 1: $FXS 2: $XLM 3: $OCEAN 4: $XRP3L 5: $BTC3S  All KuCoin results:  https://t.co/3p6BeG9Ncd Not buy signals. #DYOR
# 1476186989041000451
# I never stopped DCA-ing into $DIA $OCEAN $CTSI $OGN and $ETH.   Anyone with better picks?💁‍♂️  #buythedip #cryptocurrency #blockchain
# 1346453309180190722
# @FaizFalak3 @oceanprotocol $OCEAN looking gud after breakout  https://t.co/EnmvnfNqdM
# 1362580519590846468
# @JayHao8 @OKEx When $OCEAN
# 1392644608706842624
# @Shourya_34 $OCEAN 🚀
# 1333555958627377152
# @infected_whale @oceanprotocol @HuobiUK @HuobiGlobal @HuobiJapan @krakenfx @HuobiGlobal add $OCEAN
# 1374844588947542020
# $UBX TO THE MOON 🚀   $TEL $DENT $NPXS $KIN $UBX $VRA $DAG  $ONE $FET $CHZ $OCEAN $KCS $COTI $BTC  $ETH $XRP $DOT $LINK $RSR $SOL $LTC $ANKR  https://t.co/PNFPBluo9R
# 1373365077731115008
# @TheTradingTramp Ow yeah! You’re on fire!! 👏 First of all let me say That i’m happy That I found a trustworthy crypto partner That only gives positive vibes. No hate, thats what i like. Together we can face challenges as deep as the $ocean and as high as the moon!
# 1269901703073144833
# @777CryptoBull Hmm... I may need to take a closer look at $RUNE.  $LINK and $OCEAN are great calls in my view - privacy is so crucial. I'm also loading up on $NMR, $AGI and $ZIL.
# 1376806101987942400
# a. Allow deposit of Ocean data tokens into heroes to upgrade the clan   b. Allow deposit of $OCEAN into heroes to upgrade the clan    c. Allow deposit of Ocean Academy Certificate (NFT) into heroes to upgrade the clan   d. Allow active Ocean Dao participants to upgrade the clan
# 1567550913308692482
# Convex( $CVX)とOcean Protocol( $OCEAN)がCoinbaseに上場する模様
# 1312577911837270016
# All official links for martkist $Martk #Martkist can be found at their forum  https://t.co/tvjRu5Zo4f $eth $btc $link $xrp $om $ampl $yam $ocean $kai $mit
eth $btc $link $xrp $om $ampl $yam $ocean $kai $mitx $tmpl
# 1364822826029473795
# @coinspotau $fet $ocean $ont
# 1361550032567107588
# @CryptoCapo_ $OCEAN
# 1320681421967659008
# @StackingUSD $tomo $ocean $trb $kai $utrust $dia $coti
# 1367095879665135617
# @TheCryptoDog The literal highs and lows of crypto  $link $btc $eth $nu $algo $grt $ltc $alpha $ren $band $cvc $dnt $maker $fil $dash $ocean $knc $bnb $oxt $bat $doge $bnt $zrx $aave $xtz $xlm $uni $xrp $eos $zrx $ada $doge
# 1297342358191779841
# Te felicito compareeeee....  Anotate con 500 $Ocean 😘😉  https://t.co/LBWJZRQr2E
# 1391500892814331909
# $ocean too #CoinMata
# 1352749085770592256
# Hmm @cocacola + @MRPHSupplyChain =❤️?  $ETH $BTC #Altcoin #Cryptocurrency #Bitcoin #liquidity #news #blockchain #crypto #ethereum #xrp #ripple $VIDT $OCEAN $EWT $QNT #altszn $nano $vet $ubt $link $mitx   https://t.co/a4OPyyzNdJ
# 1490022262954770440
# #myTradeSignals  #cryptotrading BUY/SELL Signals  Previous cycle Success = 100% (28 of 28 successful)  Best trades:  $NEAR +24.4% $CHZ +21.5% $SUSHI +21% $OCEAN +20.7% $DOT +19.5%  JOIN Telegram Group-  https://t.co/9QF0jPqdi2  #Crypto #cryptocurrencies @kennekai  https://t.co/eRMUdT9xZh
# 1297832859449749504
# Martkist faucet, forum and business directory $Martk  https://t.co/Hlb1tA3GvN $eth $btc $link $xrp $om $ampl $yam $ocean $kai $mitx $tmpl
# 1582080865881845760
# CryptoMichNL $celr $atom $ocean thanks!!
# 1475862314377048067
# Ocean Protocol 1-week Social volume is up 199.71% to 11,413 with price up 19.2% to $0.92    https://t.co/0sAe5kqDbY $OCEAN #Ocean Protocol #LunarCrush
# 1406099058851291138
# ummmm i am telling you this now $Bepro will make you a lot of money.  It is a sleeping giant just building and building but yet to be put on the spotlight.   $UBT $MITX $ocean $dip $egld $sylo $fuse $link $btc $eth $frm $vra $ftm
# 1329928768174088193
# This is what I've posted 1 year ago! We are up 150% since then!!! $BTC went from 7.500$ to 18.600$!  And #Ethereum is just getting started! Happy Birthday to me 🎊🎉🎊🎉🎊🎉  #Bitcoin #cryptocurrency #ALTSEASON #BULLISH $ETH $SRK $BOLT $RWN $VIDT $TOMO $CHZ $OCEAN $UTK
# 1374079721823215627
# @fxNichola $OCEAN will melt faces this season
# 1317565729076596737
# $2.3 Billion Worth of Bitcoin in Limbo Amid OKEx Investigation.  #Limbo #Amid #OKEx #Investigation #btc ￼ #btcusdt #crypto #Bitcoin ￼ #trader #money #freedom #cryptocurrency $ocean  https://t.co/KscRFXXRcp
# 1362728725381545985
# $NEO $ICX $LINK $VET $WAVES $EOS $TOMO $WAN $NULS $NEM $QKC $ONE $FSN $CKB $REN $GEEQ $KAI $OCEAN $ETH $BTC $ADA $BTC $FRM
# 1450995657943171074
# $VRA $OLT $PBX $LINK $BTC $OCEAN $QNT  https://t.co/qXPkZc47DU
# 1230113781793148930
# $OCEAN / $BTC UPDATE: broke out sooner than predicted. Pump it to new all time highs! #altcoins #cryptocharts #crypto #trader #buylow #sellhigh  https://t.co/fAnCuc9hgv
# /var/folders/78/16lmgb053h9gw2_n1k5r5hxr0000gn/T/ipykernel_3520/1524918529.py:3: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   tweets_sentiment_df.sample(100).to_excel("./derived_datasets/sampled_tweets.xls")
